# %% [markdown]
# <a href="https://colab.research.google.com/github/zxmatilac01/cs1q4_practicaltest/blob/main/cs1q4_practicaltest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("Enter Your Name:")
quiz_score = int(input("How many quiz scores do you want to input?:"))


for score in range(quiz_score):
  quiz_score = int(input("Enter Score:"))



#total score


def sum(quiz_score):
  return

total = sum(quiz_score)
print(total)
# Out:
# Enter Your Name:lol
# How many quiz scores do you want to input?:1
# Enter Score:85
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /tmp/ipykernel_25260/811055648.py in <cell line: 0>()
#      14   return sum(quiz_score)
#      15
# ---> 16 total = sum(quiz_score)
#      17 print(total)
#
# /tmp/ipykernel_25260/811055648.py in sum(quiz_score)
#      12
#      13 def sum(quiz_score):
# ---> 14   return sum(quiz_score)
#      15
#      16 total = sum(quiz_score)
#
# ... last 1 frames repeated, from the frame below ...
#
# /tmp/ipykernel_25260/811055648.py in sum(quiz_score)
#      12
#      13 def sum(quiz_score):
# ---> 14   return sum(quiz_score)
#      15
#      16 total = sum(quiz_score)
#
# RecursionError: maximum recursion depth exceeded
